# %% [markdown]
# # Machine learning sur le titanic

# %% [markdown]
# On va construire un modèle de machine learning capable de prédire la survie au Titanic

# %% [markdown]
# Importer les données

# %%
import pandas as pd
import numpy as np

# %%
titanic = pd.read_csv("./data/titanic_train.csv")

# %%
titanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# Préparation des données

# %%
# on affiche les colonnes
titanic.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked'],
#       dtype='object')

# %% [markdown]
# On extrait les colonnes explicatives (x) et à expliquer (y)

# %%
y = titanic["Survived"]
x = titanic[['Pclass','Sex', 'Age','Fare']]

# %% [markdown]
# On va recoder les données textuelles et imputer les données manquantes

# %%
# transformer les données
from sklearn.preprocessing import OneHotEncoder,LabelEncoder
# imputer les données manquantes
from sklearn.impute import SimpleImputer

# %%
# on crée un objet
encode_sex = LabelEncoder()
# on applique la transormation
x["Sex"]=encode_sex.fit_transform(x["Sex"])
# Out:
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
# on crée un objet
impute_age = SimpleImputer()
# on applique la transormation
x["Age"]=impute_age.fit_transform(np.array(x["Age"]).reshape(-1, 1))
# Out:
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
x.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 891 entries, 0 to 890
# Data columns (total 4 columns):
# Pclass    891 non-null int64
# Sex       891 non-null int32
# Age       891 non-null float64
# Fare      891 non-null float64
# dtypes: float64(2), int32(1), int64(1)
# memory usage: 24.4 KB

# %% [markdown]
# On a bien que des données numériques

# %% [markdown]
# ## Séparation apprentissage / test

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_test,y_train,y_test = train_test_split(x,y,stratify = y)

# %%
y.value_counts(normalize=True)
# Out:
# 0    0.616162
# 1    0.383838
# Name: Survived, dtype: float64

# %%
y_train.value_counts(normalize=True)
# Out:
# 0    0.616766
# 1    0.383234
# Name: Survived, dtype: float64

# %% [markdown]
# ## Les modèles de Machine learning
#
# On va charger et ajuster les modèles de machine learing

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier

# %%
# créer des objets
modele_logit = LogisticRegression()
modele_rf = RandomForestClassifier(n_estimators=100)

# %%
# ajuster avec la méthode .fit(...)
modele_logit.fit(x_train,y_train)
# Out:
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\sklearn\linear_model\logistic.py:433: FutureWarning: Default solver will be changed to 'lbfgs' in 0.22. Specify a solver to silence this warning.
#   FutureWarning)
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=None, solver='warn',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
# on affiche les coefficients de la régression logistique
pd.DataFrame(modele_logit.coef_.T,index=x.columns)
# Out:
#                0
# Pclass -0.925113
# Sex    -2.384653
# Age    -0.020877
# Fare    0.003222

# %%
modele_rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False)

# %%
# on affiche les importances des colonnes dans les arbres générés par la forêt
pd.DataFrame(modele_rf.feature_importances_,index=x.columns)
# Out:
#                0
# Pclass  0.111328
# Sex     0.293990
# Age     0.280225
# Fare    0.314456

# %% [markdown]
# ## Validation des modèles
#
# On utilise des indicateurs pour vérifier la qualité du modèle

# %%
# tester avec .predict(...)
from sklearn.metrics import accuracy_score
print("% de bien classés pour le modèle logit :", accuracy_score(y_test,modele_logit.predict(x_test)))
print("% de bien classés pour le modèle RF :", accuracy_score( y_test,modele_rf.predict(x_test)))
# Out:
# % de bien classés pour le modèle logit : 0.7713004484304933
# % de bien classés pour le modèle RF : 0.7892376681614349

# %%
from sklearn.metrics import confusion_matrix
print("mat de confusion pour le modèle logit :", confusion_matrix(y_test,modele_logit.predict(x_test)), sep="\n")
print("mat de confusion pour le modèle RF :", confusion_matrix(y_test,modele_rf.predict(x_test)), sep="\n")
# Out:
# mat de confusion pour le modèle logit :
# [[118  19]
#  [ 32  54]]
# mat de confusion pour le modèle RF :
# [[122  15]
#  [ 32  54]]

# %% [markdown]
# ## Ajustement des hyper-paramètres
#
# On utilise Grid Search pour ajuster les hyper-paramètres du modèle

# %%
from sklearn.model_selection import GridSearchCV

# %% [markdown]
# On va donc devoir définir les hyperparamètres que l’on souhaite tester. Pour cela,
# on utilisera un dictionnaire d’hyperparamètres, par exemple :

# %%
dico_param= {"max_depth":[3,5,7,10, None], "n_estimators":[10,20,50,100,1000]}

# %% [markdown]
# On va encore utiliser l’accuracy pour valider notre modèle. Finalement, nous allons
# utiliser une validation croisée à cinq groupes pour valider les résultats.
# Le nouvel objet est le suivant :

# %%
recherche_hyper = GridSearchCV(RandomForestClassifier(), 
                               dico_param, 
                               scoring="accuracy",cv=5)

# %%
recherche_hyper.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#             max_depth=None, max_features='auto', max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, n_estimators='warn', n_jobs=None,
#             oob_score=False, random_state=None, verbose=0,
#             warm_start=False),
#        fit_params=None, iid='warn', n_jobs=None,
#        param_grid={'max_depth': [3, 5, 7, 10, None], 'n_estimators': [10, 20, 50, 100, 1000]},
#        pre_dispatch='2*n_jobs', refit=True, return_train_score='warn',
#        scoring='accuracy', verbose=0)

# %%
# la meilleure combinaison est :
recherche_hyper.best_params_
# Out:
# {'max_depth': 7, 'n_estimators': 50}

# %%
# L'ensemble des résultat apparaît ici :
pd.DataFrame(recherche_hyper.cv_results_)
# Out:
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split0_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split1_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split2_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split3_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('split4_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('mean_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
# C:\Users\s4d-asus-14\Anaconda3\lib\site-packages\sklearn\utils\deprecation.py:125: FutureWarning: You are accessing a training score ('std_train_score'), which will not be available by default any more in 0.21. If you need training scores, please set return_train_score=True
#   warnings.warn(*warn_args, **warn_kwargs)
#     mean_fit_time  std_fit_time  mean_score_time  std_score_time  \
# 0        0.019042      0.006438         0.004613        0.001874
# 1        0.028568      0.005115         0.003860        0.002089
# 2        0.075827      0.006061         0.008642        0.003002
# 3        0.146950      0.004673         0.013520        0.001495
# 4        1.478071      0.011556         0.130022        0.002256
# 5        0.018882      0.001049         0.003638        0.000805
# 6        0.036247      0.002062         0.005496        0.001856
# 7        0.080839      0.003593         0.008436        0.001881
# 8        0.162997      0.009353         0.014720        0.003363
# 9        1.631042      0.053028         0.141542        0.010206
# 10       0.021591      0.001377         0.003844        0.002604
# 11       0.037046      0.000989         0.005114        0.001530
# 12       0.086783      0.005190         0.010024        0.001769
# 13       0.172878      0.002607         0.015224        0.002436
# 14       1.687883      0.076067         0.148817        0.003278
# 15       0.021168      0.001331         0.003510        0.002183
# 16       0.038894      0.003570         0.005446        0.001277
# 17       0.092811      0.002592         0.010910        0.002700
# 18       0.188018      0.009499         0.016927        0.001642
# 19       1.830810      0.115720         0.148781        0.004867
# 20       0.021592      0.002531         0.004937        0.001646
# 21       0.041893      0.004463         0.005476        0.002094
# 22       0.092920      0.005130         0.008767        0.001659
# 23       0.181452      0.005735         0.016227        0.001181
# 24       1.767879      0.027057         0.154097        0.015419
#
#    param_max_depth param_n_estimators  \
# 0                3                 10
# 1                3                 20
# 2                3                 50
# 3                3                100
# 4                3               1000
# 5                5                 10
# 6                5                 20
# 7                5                 50
# 8                5                100
# 9                5               1000
# 10               7                 10
# 11               7                 20
# 12               7                 50
# 13               7                100
# 14               7               1000
# 15              10                 10
# 16              10                 20
# 17              10                 50
# 18              10                100
# 19              10               1000
# 20            None                 10
# 21            None                 20
# 22            None                 50
# 23            None                100
# 24            None               1000
#
#                                        params  split0_test_score  \
# 0        {'max_depth': 3, 'n_estimators': 10}           0.859259
# 1        {'max_depth': 3, 'n_estimators': 20}           0.844444
# 2        {'max_depth': 3, 'n_estimators': 50}           0.874074
# 3       {'max_depth': 3, 'n_estimators': 100}           0.844444
# 4      {'max_depth': 3, 'n_estimators': 1000}           0.851852
# 5        {'max_depth': 5, 'n_estimators': 10}           0.837037
# 6        {'max_depth': 5, 'n_estimators': 20}           0.866667
# 7        {'max_depth': 5, 'n_estimators': 50}           0.851852
# 8       {'max_depth': 5, 'n_estimators': 100}           0.859259
# 9      {'max_depth': 5, 'n_estimators': 1000}           0.866667
# 10       {'max_depth': 7, 'n_estimators': 10}           0.859259
# 11       {'max_depth': 7, 'n_estimators': 20}           0.837037
# 12       {'max_depth': 7, 'n_estimators': 50}           0.874074
# 13      {'max_depth': 7, 'n_estimators': 100}           0.837037
# 14     {'max_depth': 7, 'n_estimators': 1000}           0.844444
# 15      {'max_depth': 10, 'n_estimators': 10}           0.859259
# 16      {'max_depth': 10, 'n_estimators': 20}           0.829630
# 17      {'max_depth': 10, 'n_estimators': 50}           0.859259
# 18     {'max_depth': 10, 'n_estimators': 100}           0.844444
# 19    {'max_depth': 10, 'n_estimators': 1000}           0.859259
# 20    {'max_depth': None, 'n_estimators': 10}           0.807407
# 21    {'max_depth': None, 'n_estimators': 20}           0.859259
# 22    {'max_depth': None, 'n_estimators': 50}           0.837037
# 23   {'max_depth': None, 'n_estimators': 100}           0.859259
# 24  {'max_depth': None, 'n_estimators': 1000}           0.859259
#
#     split1_test_score  split2_test_score  ...  mean_test_score  \
# 0            0.813433           0.781955  ...         0.827844
# 1            0.805970           0.721805  ...         0.811377
# 2            0.805970           0.751880  ...         0.823353
# 3            0.791045           0.774436  ...         0.814371
# 4            0.805970           0.759398  ...         0.817365
# 5            0.783582           0.759398  ...         0.809880
# 6            0.813433           0.751880  ...         0.830838
# 7            0.813433           0.759398  ...         0.829341
# 8            0.828358           0.759398  ...         0.832335
# 9            0.828358           0.759398  ...         0.833832
# 10           0.813433           0.781955  ...         0.833832
# 11           0.805970           0.789474  ...         0.827844
# 12           0.813433           0.751880  ...         0.836826
# 13           0.813433           0.766917  ...         0.829341
# 14           0.820896           0.759398  ...         0.833832
# 15           0.776119           0.729323  ...         0.802395
# 16           0.805970           0.766917  ...         0.811377
# 17           0.798507           0.744361  ...         0.815868
# 18           0.813433           0.781955  ...         0.820359
# 19           0.805970           0.766917  ...         0.823353
# 20           0.798507           0.796992  ...         0.817365
# 21           0.805970           0.774436  ...         0.826347
# 22           0.798507           0.796992  ...         0.817365
# 23           0.805970           0.766917  ...         0.817365
# 24           0.798507           0.781955  ...         0.821856
#
#     std_test_score  rank_test_score  split0_train_score  split1_train_score  \
# 0         0